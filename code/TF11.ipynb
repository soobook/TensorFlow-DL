# %% [markdown]
# # 11회차: RNN을 활용한 항공 여행자 수 예측 (1) - 개념 및 데이터 분석

# %%
# kagglehub는 colab에 이미 설치된 것을 확인
# !pip show kagglehub
# Out:
# Name: kagglehub
# Version: 0.3.12
# Summary: Access Kaggle resources anywhere
# Home-page: https://github.com/Kaggle/kagglehub
# Author:
# Author-email: Kaggle <support@kaggle.com>
# License: Apache License
#                            Version 2.0, January 2004
#                         http://www.apache.org/licenses/
#
#    TERMS AND CONDITIONS FOR USE, REPRODUCTION, AND DISTRIBUTION
#
#    1. Definitions.
#
#       "License" shall mean the terms and conditions for use, reproduction,
#       and distribution as defined by Sections 1 through 9 of this document.
#
#       "Licensor" shall mean the copyright owner or entity authorized by
#       the copyright owner that is granting the License.
#
#       "Legal Entity" shall mean the union of the acting entity and all
#       other entities that control, are controlled by, or are under common
#       control with that entity. For the purposes of this definition,
#       "control" means (i) the power, direct or indirect, to cause the
# ...

# %%
import kagglehub
import pandas as pd
import os

# 데이터셋 다운로드
path = kagglehub.dataset_download("pattnaiksatyajit/air-passengers")
print("Path to dataset files:", path)

# CSV 파일 경로 찾기 (해당 데이터셋에는 'AirPassengers.csv' 파일이 있음)
csv_file_path = os.path.join(path, "AirPassengers.csv")

# CSV 로드
df = pd.read_csv(csv_file_path)

# 일부 데이터 출력
print("\n데이터 일부 미리보기:")
df.info()
# Out:
# Path to dataset files: /kaggle/input/air-passengers
#
# 데이터 일부 미리보기:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.head() # #Passengers 단위: 천명
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %% [markdown]
# ## 종료
